# %% [markdown]
# # Execution of the benchmark here
# To execute the benchmark another environment is used since the benchmark versions are deprecated

# %%
import sys
sys.path.append("/home/lll/thesis_lf_cnn/baselines/benchmark/Code/BenchmarkModel/LoadForecasting/models")
# !cd ../baselines/benchmark/Code/BenchmarkModel/LoadForecasting/models/ && python3 cnn.py --gpu 1
# Out:
# after merge: config, {'model_params': {'model_name': 'cnn', 'dropout': [0.1], 'hidden_layers': [[32, 64]], 'kernel_size': [[4, 4]], 'stride': [[2, 2]], 'pooling': ['max']}, 'exp_params': {'sliding_window': [120], 'selection_metric': 'RMSE', 'train_valid_ratio': 0.9, 'external_features': ['month_day', 'weekday', 'holiday', 'DHI', 'DNI', 'GHI', 'Dew Point', 'Solar Zenith Angle', 'Wind Speed', 'Relative Humidity', 'Temperature'], 'test_flag': False, 'last_version': 4, 'batch_size': [50], 'learning_rate': [0.01], 'num_workers': 0, 'normalization': ['minmax'], 'prediction_interval': 0.95, 'data_folder': '/media/lll/T9/PSML/processed_dataset/forecasting'}, 'trainer_params': {'max_epochs': 2, 'gpus': 1}, 'logging_params': {'save_dir': './../logs', 'name': 'cnn', 'manual_seed': 0}}
# gpus:  1
# log_dir: ./../logs/cnn/version_2
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | CNNNet | 344 K
# ---------------------------------
# 344 K     Trainable params
# 0         Non-trainable params
# 344 K     Total params
# 1.380     Total estimated model params size (MB)
# Epoch 0:  89%|████████▉ | 66/74 [00:00<00:00, 419.75it/s, loss=0.00518, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Epoch 0: 100%|██████████| 74/74 [00:00<00:00, 431.56it/s, loss=0.00518, v_num=0]
#                                                                                 Epoch 0, global step 65: avg_val_metric reached 0.17718 (best 0.17718), saving model to "./../logs/cnn/version_2/CAISO_zone_1_2018/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=00-avg_val_metric=0.177.ckpt" as top 1
# Epoch 1:  89%|████████▉ | 66/74 [00:00<00:00, 474.71it/s, loss=0.00261, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Epoch 1: 100%|██████████| 74/74 [00:00<00:00, 167.66it/s, loss=0.00261, v_num=0]
#                                                                                 Epoch 1, global step 131: avg_val_metric reached 0.10500 (best 0.10500), saving model to "./../logs/cnn/version_2/CAISO_zone_1_2018/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=01-avg_val_metric=0.105.ckpt" as top 1
# Epoch 1: 100%|██████████| 74/74 [00:00<00:00, 164.46it/s, loss=0.00261, v_num=0]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# Load checkpoint from ./../logs/cnn/version_2/CAISO_zone_1_2018/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=01-avg_val_metric=0.105.ckpt...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing:  93%|███████████████████████████▉  | 805/865 [00:00<00:00, 2011.23it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████| 865/865 [00:00<00:00, 1217.09it/s]
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | CNNNet | 344 K
# ---------------------------------
# 344 K     Trainable params
# 0         Non-trainable params
# 344 K     Total params
# 1.380     Total estimated model params size (MB)
# Epoch 0:  89%|████████▉ | 66/74 [00:00<00:00, 474.14it/s, loss=0.00556, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Epoch 0: 100%|██████████| 74/74 [00:00<00:00, 482.94it/s, loss=0.00556, v_num=0]
#                                                                                 Epoch 0, global step 65: avg_val_metric reached 0.18933 (best 0.18933), saving model to "./../logs/cnn/version_2/CAISO_zone_1_2019/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=00-avg_val_metric=0.189.ckpt" as top 1
# Epoch 1:  89%|████████▉ | 66/74 [00:00<00:00, 457.21it/s, loss=0.00339, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Epoch 1: 100%|██████████| 74/74 [00:00<00:00, 219.67it/s, loss=0.00339, v_num=0]
#                                                                                 Epoch 1, global step 131: avg_val_metric reached 0.15287 (best 0.15287), saving model to "./../logs/cnn/version_2/CAISO_zone_1_2019/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=01-avg_val_metric=0.153.ckpt" as top 1
# Epoch 1: 100%|██████████| 74/74 [00:00<00:00, 214.78it/s, loss=0.00339, v_num=0]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# Load checkpoint from ./../logs/cnn/version_2/CAISO_zone_1_2019/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=01-avg_val_metric=0.153.ckpt...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing:  92%|███████████████████████████▌  | 796/865 [00:00<00:00, 1962.59it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████| 865/865 [00:00<00:00, 1189.16it/s]
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | CNNNet | 344 K
# ---------------------------------
# 344 K     Trainable params
# 0         Non-trainable params
# 344 K     Total params
# 1.380     Total estimated model params size (MB)
# Epoch 0:  89%|████████▉ | 67/75 [00:00<00:00, 452.81it/s, loss=0.00508, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Epoch 0: 100%|██████████| 75/75 [00:00<00:00, 470.41it/s, loss=0.00508, v_num=0]
#                                                                                 Epoch 0, global step 66: avg_val_metric reached 0.18017 (best 0.18017), saving model to "./../logs/cnn/version_2/CAISO_zone_1_2020/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=00-avg_val_metric=0.180.ckpt" as top 1
# Epoch 1:  89%|████████▉ | 67/75 [00:00<00:00, 478.77it/s, loss=0.00369, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Epoch 1: 100%|██████████| 75/75 [00:00<00:00, 220.24it/s, loss=0.00369, v_num=0]
#                                                                                 Epoch 1, global step 133: avg_val_metric reached 0.14845 (best 0.14845), saving model to "./../logs/cnn/version_2/CAISO_zone_1_2020/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=01-avg_val_metric=0.148.ckpt" as top 1
# Epoch 1: 100%|██████████| 75/75 [00:00<00:00, 215.55it/s, loss=0.00369, v_num=0]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# CNNNet(
#   (cnn_layer): Sequential(
#     (0): Sequential(
#       (0): Conv1d(14, 32, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (1): MaxPool1d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): Linear(in_features=320, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=1024, out_features=6, bias=True)
#   )
# )
# Total number of parameters: 0.345 M
# Load checkpoint from ./../logs/cnn/version_2/CAISO_zone_1_2020/param_B50_D0.1_H[32, 64]_K[4, 4]_L0.01_Nminmax_Pmax_S120_S[2, 2]/version_0/best-epoch=01-avg_val_metric=0.148.ckpt...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing:  91%|███████████████████████████▎  | 787/865 [00:00<00:00, 1960.31it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████| 865/865 [00:00<00:00, 1200.88it/s]
# Traceback (most recent call last):
#   File "cnn.py", line 288, in <module>
#     grid_search_cnn(config, num_files=args['num_files'])
#   File "cnn.py", line 248, in grid_search_cnn
#     run_evaluate_V3(config=evaluate_config, verbose=False)
#   File "/home/lll/thesis_lf_cnn/baselines/benchmark/Code/BenchmarkModel/LoadForecasting/models/utils.py", line 74, in run_evaluate_V3
#     data_folder = config['exp_params']['data_folder']
# KeyError: 'data_folder'
